# %%
import pandas as pd
from sklearn import datasets as ds

data = ds.load_diabetes(as_frame = True)
df = data['data']
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
df['Name of Patient']=['ram','John', 'Jane', 'Michael', 'Emily', 'William', 'Sophia', 'David', 'Olivia', 'James', 'Ava',
    'Robert', 'Isabella', 'Joseph', 'Mia', 'Charles', 'Abigail', 'Thomas', 'Elizabeth', 'Daniel', 'Amelia',
    'Matthew', 'Ella', 'George', 'Sofia', 'Jennifer', 'Harper', 'Richard', 'Liam', 'Mary', 'Evelyn', 'Linda',
    'Aiden', 'Grace', 'Maria', 'Emma', 'Nancy', 'Victoria', 'Paul', 'Chloe', 'Mark', 'Avery', 'Edward', 'Eleanor',
    'Steven', 'Ethan', 'Margaret', 'Hannah', 'Brian', 'Addison', 'Kevin', 'Natalie', 'Ronald', 'Lily', 'Timothy',
    'Lillian', 'Jason', 'Aubrey', 'Kenneth', 'Zoe', 'Anthony', 'Layla', 'Donald', 'Brooklyn', 'Ryan', 'Hailey',
    'George', 'Leah', 'Lisa', 'Samantha', 'Angela', 'Audrey', 'Henry', 'Aria', 'Frank', 'Skylar', 'Dennis', 'Claire',
    'Rebecca', 'Bella', 'Jerry', 'Penelope', 'Larry', 'Serenity', 'Tyler', 'Zoey', 'Aaron', 'Harmony', 'Douglas',
    'Hazel', 'Jose', 'Ellie', 'Peter', 'Violet', 'Adam', 'Stella', 'Nicholas', 'Paisley', 'Walter', 'Nova', 'Harold',
    'Emilia', 'Gloria', 'Madison', 'Austin', 'Willow', 'Eugene', 'Everly', 'Carl', 'Kinsley', 'Arthur', 'Maya',
    'Ryan', 'Madelyn', 'Benjamin', 'Naomi', 'Russell', 'Eliza', 'Howard', 'Elena', 'Andrew', 'Sarah', 'Juan',
    'Addison', 'Louis', 'Mackenzie', 'Bobby', 'Aurora', 'Samuel', 'Melanie', 'Raymond', 'Gianna', 'Patrick', 'Camila',
    'Henry', 'Katherine', 'Johnny', 'Luna', 'Philip', 'Nevaeh', 'Ralph', 'Aaliyah', 'Stephen', 'Savannah', 'Alan',
    'Anna', 'Bernard', 'Ruby', 'Jesse', 'Sofia', 'Frederick', 'Serena', 'Lawrence', 'Isabelle', 'Terry', 'Valentina',
    'Joe', 'Sophie', 'Albert', 'Alice', 'Alexander', 'Lilly', 'Roy', 'Zara', 'Jonathan', 'Riley', 'Wayne', 'Lucy',
    'Billy', 'Alexa', 'Willie', 'Sadie', 'Stanley', 'Makayla', 'Jack', 'Nora', 'Jeremy', 'Ellie', 'Kyle', 'Haley',
    'Brandon', 'Ariana', 'Randy', 'Lyla', 'Phillip', 'Samantha', 'Nicholas', 'Annabelle', 'Randy', 'Mya', 'Roger',
    'Delilah', 'Darrell', 'Isabel', 'Curtis', 'Vivian', 'Marvin', 'Kiara', 'Gerald', 'Lila', 'Logan', 'Michelle',
    'Arthur', 'Liliana', 'Marvin', 'Alyssa', 'Reginald', 'Rylee', 'Nathaniel', 'Sara', 'Martin', 'Cora', 'Lawrence',
    'Brianna', 'Gerard', 'Bailey', 'Oscar', 'Allison', 'Clarence', 'Jasmine', 'Milton', 'Leila', 'Keith', 'Adeline',
    'Samuel', 'Molly', 'Gregory', 'Alexandra', 'Theodore', 'Charlie', 'Clifford', 'Emery', 'Edwin', 'Hazel', 'Rodney',
    'London', 'Leroy', 'Genevieve', 'Everett', 'Luna', 'Lester', 'Callie', 'Freddie', 'Melody', 'Lloyd', 'Athena',
    'Christian', 'Anastasia', 'Stuart', 'Amaya', 'Clyde', 'Alaina', 'Alfred', 'Daisy', 'Joel', 'Finley', 'Leo', 'Diana',
    'Jay', 'Giselle', 'Victor', 'Sage', 'Leslie', 'Harley', 'Wallace', 'Emerson', 'Terrance', 'Kylie', 'Alvin', 'Adalyn',
    'Maurice', 'Valeria', 'Franklin', 'June', 'Wesley', 'Tessa', 'Emmanuel', 'Malia', 'Jared', 'Adelyn', 'Edgar',
    'Sawyer', 'Ricky', 'Eloise', 'Alex', 'Ximena', 'Neil', 'Adelaide', 'Gilbert', 'Lia', 'Rodney', 'Matilda', 'Rick',
    'Jordyn', 'Jackie', 'Nina', 'Stanley', 'Juliette', 'Leon', 'Sienna', 'Manuel', 'Justice', 'Lyle', 'Dakota', 'Jordan',
    'Chelsea', 'Ben', 'Daniela', 'Dominic', 'Daleyza', 'Harvey', 'Lilah', 'Norman', 'Esther', 'Keith', 'Kayla', 'Vernon',
    'Rosalie', 'Calvin', 'Selena', 'Brett', 'Lola', 'Paul', 'Amara', 'Dale', 'Lena', 'Eddie', 'Stephanie', 'Frederick',
    'Brynlee', 'Bradley', 'Ana', 'Rudolph', 'Gemma', 'Isaac', 'Julia', 'Emil', 'Josie', 'Bryan', 'Presley', 'Elmer',
    'Harlow', 'Walter', 'Hayden', 'Alexis', 'Harvey', 'Jordan', 'Elijah', 'Peyton', 'Clyde', 'Elliana', 'Travis',
    'Nyla', 'Gordon', 'Mariah', 'Neil', 'Elise', 'Leonard', 'Hallie', 'Melvin', 'Evangeline', 'Jerome', 'Journey',
    'Jesse', 'Celeste', 'Ruben', 'Leia', 'Leroy', 'Maddison', 'Everett', 'Remi', 'Mario', 'Catherine', 'Rufus',
    'Ember', 'Julio', 'Emersyn', 'Sidney', 'Bianca', 'Benny', 'Ruth', 'Morris', 'Kali', 'Owen', 'Yara', 'Don', 'Talia',
    'Seth', 'Haylee', 'Cameron', 'Mckinley', 'Ramon', 'Elaina', 'Curtis', 'Mikayla', 'Clifton', 'Lana', 'Lloyd',
    'Kiara', 'Hector', 'Fiona', 'Bryant', 'Alina', 'Darryl', 'Phoebe', 'Troy', 'Haylee', 'Cameron', 'Mckinley', 'Ramon', 'Elaina', 'Curtis', 'Mikayla', 'Clifton', 'Lana', 'Lloyd', 'Haylee', 'Cameron', 'Mckinley', 'Ramon', 'Elaina', 'Curtis', 'Mikayla', 'Clifton', 'Lana', 'Lloyd', 'Haylee', 'Cameron', 'Mckinley', 'Ramon', 'Haylee', 'Cameron', 'Mckinley', 'Ramon', 'Elaina', 'Curtis', 'Mikayla', 'Clifton', 'Lana', 'Lloyd', 'Haylee', 'Cameron'  ]

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6 Name of Patient
# ...

# %%
df['Aadhar number']=[123456789012,987654321012,456789012345,210987654321,654321012345,543210987654,987012345678,678987012345,890123456789,789012345678,234567890123,345678901234,567890123456,678901234567,890123456789,901234567890,345678901234,123456789012,890123456789, 456789012345, 987654321012,
    234567890123,
    567890123456,
    890123456789,
    123456789012,
    210987654321,
    654321012345,
    543210987654,
    987012345678,
    678987012345,
    678901234567,
    345678901234,
    789012345678,
    234567890123,
    890123456789,
    456789012345,
    789012345678,
    987654321012,
    543210987654,
    210987654321,
    234567890123,
 52, 81, 59, 11, 67, 93, 28, 41, 62, 73, 48, 86, 64, 22, 79, 55, 33, 92, 51, 16, 29, 74, 35, 58, 44, 18, 68, 
 46, 23, 12, 97, 45, 26, 39, 69, 31, 72, 85, 54, 21, 65, 34, 75, 57, 42, 99, 66, 83, 61, 32, 56, 71, 88, 94, 
 82, 76, 13, 49, 87, 63, 27, 95, 77, 38, 84, 19, 53, 36, 91, 43, 25, 78, 17, 53, 24, 79, 16, 29, 88, 65, 92, 
 11, 37, 58, 42, 96, 44, 63, 78, 52, 33, 71, 94, 81, 69, 49, 25, 16, 82, 39, 53, 27, 61, 74, 88, 36, 12, 56, 
 22, 47, 66, 75, 32, 45, 91, 19, 28, 46, 67, 55, 99, 72, 89, 59, 34, 83, 17, 43, 29, 57, 76, 68, 21, 95, 38, 
 64, 73, 54, 31, 14, 86, 18, 98, 87, 37, 93, 24, 79, 67, 43, 33, 53, 66, 11, 52, 71, 46, 84, 22, 16, 35, 55, 
 92, 75, 68, 25, 89, 59, 47, 78, 41, 14, 62, 28, 56, 74, 98, 19, 63, 32, 72, 45, 81, 21, 96, 49, 37, 64, 93, 
 88, 57, 18, 91, 69, 26, 61, 82, 48, 31, 99, 12, 76, 29, 51, 38, 17, 44, 27, 54, 95, 73, 67, 86, 39, 85, 11, 
 66, 52, 45, 77, 25, 62, 89, 31, 49, 71, 18, 88, 34, 53, 29, 92, 12, 55, 38, 67, 21, 72, 47, 96, 14, 81, 36, 
 69, 24, 73, 59, 19, 44, 76, 22, 57, 64, 93, 68, 33, 11, 86, 61, 43, 99, 75, 46, 52, 25, 14, 67, 32, 59, 91, 
 38, 71, 88, 76, 47, 22, 35, 12, 66
]

# %%
df
# Out:
#      age       sex       bmi        bp        s1        s2        s3  \
# 0     87  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1     11 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2     53  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3     98 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4     22 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..   ...       ...       ...       ...       ...       ...       ...
# 437   47  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438   22  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439   35  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440   12 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441   66 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6 Name of Patient  Aadhar number  Age
# ...

# %%
del df['Age']     # to delete any column

# %%
df
# Out:
#      age       sex       bmi        bp        s1        s2        s3  \
# 0     87  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1     11 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2     53  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3     98 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4     22 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..   ...       ...       ...       ...       ...       ...       ...
# 437   47  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438   22  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439   35  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440   12 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441   66 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6 Name of Patient  Aadhar number
# 0   -0.002592  0.019907 -0.017646             ram   123456789012
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(17,17))
sns.scatterplot(x="Age" , y='Name of Patient', data =df)
# Out:
# <Axes: xlabel='Age', ylabel='Name of Patient'>

# %%
df.isnull()
# Out:
#        age    sex    bmi     bp     s1     s2     s3     s4     s5     s6  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 437  False  False  False  False  False  False  False  False  False  False
# 438  False  False  False  False  False  False  False  False  False  False
# 439  False  False  False  False  False  False  False  False  False  False
# 440  False  False  False  False  False  False  False  False  False  False
# 441  False  False  False  False  False  False  False  False  False  False
#
#      Name of Patient  Aadhar number    Age
# ...

# %%
df[df['age'].isna()]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, bp, s1, s2, s3, s4, s5, s6, Name of Patient, Aadhar number]
# Index: []

# %% [markdown]
# # since there is no null values it is not showing anything

# %%
df.at[1,'age']=28  # by using df.at we make specific cell null

# %%
df
# Out:
#       age       sex       bmi        bp        s1        s2        s3  \
# 0    87.0  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1    28.0 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    53.0  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3    98.0 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    22.0 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..    ...       ...       ...       ...       ...       ...       ...
# 437  47.0  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438  22.0  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  35.0  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440  12.0 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441  66.0 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6 Name of Patient  Aadhar number
# ...

# %%
del df[1,'age']

# %%
del df['age',1]

# %% [markdown]
# Making a Row 1 and column 5 as null

# %%
df.at[1,'s1']=None

# %%
df
# Out:
#       age       sex       bmi        bp        s1        s2        s3  \
# 0    87.0  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1    28.0 -0.044642 -0.051474 -0.026328       NaN -0.019163  0.074412
# 2    53.0  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3    98.0 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    22.0 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..    ...       ...       ...       ...       ...       ...       ...
# 437  47.0  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438  22.0  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  35.0  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440  12.0 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441  66.0 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6 Name of Patient  Aadhar number
# ...

# %% [markdown]
# Making a Row 2 and column 3 as null

# %%
df.at[2,'bmi']=None

# %%
df
# Out:
#       age       sex       bmi        bp        s1        s2        s3  \
# 0    87.0  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1    28.0 -0.044642 -0.051474 -0.026328       NaN -0.019163  0.074412
# 2    53.0  0.050680       NaN -0.005670 -0.045599 -0.034194 -0.032356
# 3    98.0 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    22.0 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..    ...       ...       ...       ...       ...       ...       ...
# 437  47.0  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438  22.0  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  35.0  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440  12.0 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441  66.0 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6 Name of Patient  Aadhar number
# ...

# %% [markdown]
# Making a Row 5 and column 11 as null

# %%
df.at[5,'Name of Patient']=None

# %%
df
# Out:
#       age       sex       bmi        bp        s1        s2        s3  \
# 0    87.0  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1    28.0 -0.044642 -0.051474 -0.026328       NaN -0.019163  0.074412
# 2    53.0  0.050680       NaN -0.005670 -0.045599 -0.034194 -0.032356
# 3    98.0 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    22.0 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..    ...       ...       ...       ...       ...       ...       ...
# 437  47.0  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438  22.0  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  35.0  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440  12.0 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441  66.0 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6 Name of Patient  Aadhar number
# ...

# %% [markdown]
# Making a Row 96 and column 5 as null

# %%
df.at[96,'s1']=None

# %%
df
# Out:
#       age       sex       bmi        bp        s1        s2        s3  \
# 0    87.0  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1    28.0 -0.044642 -0.051474 -0.026328       NaN -0.019163  0.074412
# 2    53.0  0.050680       NaN -0.005670 -0.045599 -0.034194 -0.032356
# 3    98.0 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    22.0 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..    ...       ...       ...       ...       ...       ...       ...
# 437  47.0  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438  22.0  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  35.0  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440  12.0 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441  66.0 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6 Name of Patient  Aadhar number
# ...

# %% [markdown]
# Making a Row 1 and column 1 as null

# %%
df.at[1,'age']=None

# %%
df
# Out:
#       age       sex       bmi        bp        s1        s2        s3  \
# 0    87.0  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1     NaN -0.044642 -0.051474 -0.026328       NaN -0.019163  0.074412
# 2    53.0  0.050680       NaN -0.005670 -0.045599 -0.034194 -0.032356
# 3    98.0 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    22.0 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..    ...       ...       ...       ...       ...       ...       ...
# 437  47.0  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438  22.0  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  35.0  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440  12.0 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441  66.0 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6 Name of Patient  Aadhar number
# ...

# %%
df[df['age'].isna()]
# Out:
#    age       sex       bmi        bp  s1        s2        s3        s4  \
# 1  NaN -0.044642 -0.051474 -0.026328 NaN -0.019163  0.074412 -0.039493
#
#          s5        s6 Name of Patient  Aadhar number
# 1 -0.068332 -0.092204            John   987654321012

# %%
df[df['sex'].isna()]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, bp, s1, s2, s3, s4, s5, s6, Name of Patient, Aadhar number]
# Index: []

# %%
df[df['bmi'].isna()]
# Out:
#     age      sex  bmi       bp        s1        s2        s3        s4  \
# 2  53.0  0.05068  NaN -0.00567 -0.045599 -0.034194 -0.032356 -0.002592
#
#          s5       s6 Name of Patient  Aadhar number
# 2  0.002861 -0.02593            Jane   456789012345

# %%
df[df['s1'].isna()]
# Out:
#      age       sex       bmi        bp  s1        s2        s3        s4  \
# 1    NaN -0.044642 -0.051474 -0.026328 NaN -0.019163  0.074412 -0.039493
# 96  55.0  0.050680  0.009961  0.049415 NaN -0.012274 -0.043401  0.034309
#
#           s5        s6 Name of Patient  Aadhar number
# 1  -0.068332 -0.092204            John   987654321012
# 96  0.060791  0.032059        Nicholas   789012345678

# %%
df[df['s2'].isna()]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, bp, s1, s2, s3, s4, s5, s6, Name of Patient, Aadhar number]
# Index: []

# %%
df[df['s3'].isna()]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, bp, s1, s2, s3, s4, s5, s6, Name of Patient, Aadhar number]
# Index: []

# %%
df[df['s4'].isna()]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, bp, s1, s2, s3, s4, s5, s6, Name of Patient, Aadhar number]
# Index: []

# %%
df[df['s5'].isna()]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, bp, s1, s2, s3, s4, s5, s6, Name of Patient, Aadhar number]
# Index: []

# %%
df[df['s6'].isna()]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, bp, s1, s2, s3, s4, s5, s6, Name of Patient, Aadhar number]
# Index: []

# %%
df[df['Name of Patient'].isna()]
# Out:
#     age       sex       bmi        bp        s1        s2        s3        s4  \
# 5  46.0 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277 -0.076395
#
#          s5        s6 Name of Patient  Aadhar number
# 5 -0.041176 -0.096346            None   543210987654

# %%
df[df['Aadhar number'].isna()]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, bp, s1, s2, s3, s4, s5, s6, Name of Patient, Aadhar number]
# Index: []
